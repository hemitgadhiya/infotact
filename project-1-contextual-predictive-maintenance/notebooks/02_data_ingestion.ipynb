# %% [markdown]
# # Data Ingestion: AI4I Predictive Maintenance Dataset
#
# This notebook loads the AI4I 2020 Predictive Maintenance dataset, validates its schema, and examines the class imbalance in machine failures. This is the foundation for all downstream feature engineering and modeling in this project.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/raw/ai4i2020.csv")
print("Shape:", df.shape)
print("\nColumns:", df.columns.tolist())
df.head()

# %%
print("Data Types:\n", df.dtypes)
print("\nNull Values:\n", df.isnull().sum())

# %% [markdown]
# ## Class imbalance check
#
# Machine failures are rare events. Understanding the class imbalance here is critical, since it directly motivates using Macro F1 (instead of accuracy) and SMOTE oversampling in later stages of the pipeline.

# %%
print("Failure Distribution:")
print(df['Machine failure'].value_counts())
print("\nPercentage:")
print(df['Machine failure'].value_counts(normalize=True).mul(100).round(2))

# %%
df['Machine failure'].value_counts().plot(kind='bar', color=['green','red'], title='Failure vs No-Failure')
plt.xlabel('Machine Failure')
plt.ylabel('Count')
plt.tight_layout()
plt.show()
